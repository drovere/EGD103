# %% [markdown]
# <div style="background-color: #ccccff ; padding:10px; font-size:x-large; font-weight: bold">
# EGD103 Assignment 2 - Analysing QLD Traffic Data
# </div>

# %% [markdown]
# In this assignment, you will be analysing hourly traffic road traffic data for QLD. This data is collected with traffic cameras by the Department of Transport and Main Roads. You will analyse this data to answer questions about what factors influence
# traffic counts.
#
# The main dataset for this assignment ‘qld_traffic_2023.csv’ is publicly available
# data collected from the Queensland Government’s Open Data Portal. It includes
# traffic count data for 2023 based on factors such as location, direction of travel,
# time and day of week. The raw data was collected from https://www.data.qld.gov.au/dataset/queensland-traffic-data-averaged-by-hour-of-day-and-day-of-week.
# A data dictionary named ‘field-descriptions.csv’ is available. This gives a
# description of each variable in the dataset. Please refer to it if you are unsure
# about what information is contained in each column.
#
# The assignment is split into four parts which are equally weighted:
# * **Part A:** Here you will wrangle the data to ensure it is suitable for analysis.
# * **Part B:** Here you will use aggregation and visualisation to answer some questions about the data.
# * **Part C:** Here you will integrate some programming theory with the data to create a program.
# * **Part D:** Here you will reflect on your learning from completing the assignment.
#
# You will also be marked on your code quality and an in-class activity after assignment submission. View the CRA on Canvas for more details on how you will be graded.

# %% [markdown]
# <div style="background-color: #ffcccc; padding:10px">
#
# ## General Rules and Restrictions
# * You must use Jupyter in the cloud (on https://jupyter.eres.qut.edu.au) to develop your solution.
# * For the assignments you cannot work with friends or colleagues, or get help from anyone other than the EGD103 teaching team - it needs to be entirely your own work.
# * You cannot use AI tools such as ChatGPT or Copilot to help develop your solution.
# * You can use the imports included in this template to complete this assignment. If you would like to use additional imports you will need approval from the unit coordinator.
# * You should be using formatted Markdown cells to communicate your process and outcomes in each section of the assignment. Clear communication and formatting are required to achieve high marks.
# * You may add extra code cells and Markdown cells to this template at your discretion, but do not remove any cells.
# * You should only use Python language features that have been taught within this unit. If you use other features we will suspect acadamic misconduct and require you to attend meeting to authenticate your learning.
# </div>

# %% [markdown]
# <div style="background-color: #b2efb2; padding:10px; font-size:small; font-weight: bold">
#
# ## Student Details
# <p>Task: Using the Markdown cell below, write your name and student number. Also briefly describe any previous programming experience you may have had (if any).</p>

# %% [markdown]
# * Name:
# * Student number:
# * Previous programming experience:

# %% [markdown]
# ## Allowed Imports
# You are allowed to use the imports given in the cell below when completing the assignment. Run the cell to import. Do not repeat yourself by adding import statements later in the assignment.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ***

# %% [markdown]
# <div style="background-color: #b2efb2; padding:10px; font-size:small; font-weight: bold">
#
# ## Part A: Inspecting and preparing data

# %% [markdown]
# ### A1: Importing data
# Import the main dataset as a pandas dataframe. Inspect the data to ensure it has been imported correctly.
#
# Useful functions: <code>pd.read_csv</code>.

# %%
# write your code here

# %% [markdown]
# ### A2: Creating a Weekly Total Column
# Add a computed column named TOTAL that contains the sum of the counts from all 7 days.

# %%
# insert code here

# %% [markdown]
# ### A3: Creating a Start Time Column
# Currently time is recorded as an object in the HOURS column. It would be much better to have a column that used a numeric representation for time. Create a new column called START_TIME that contains the start time from the HOURS column interval represented as an integer.

# %%
# insert code here

# %% [markdown]
# ### A4: Further inspection
# Conduct some further inspection to ensure the data is ready for analysis. You may want to consider the following:
# * Are there any missing values?
# * Are there any outliers?
# * Domain / format checks
#
# Describe your inspection process and summarise your findings in the Markdown cell below.

# %% [markdown]
# Write your inspection summary here

# %%
# write your code here

# %% [markdown]
# <div style="background-color: #b2efb2; padding:10px; font-size:small; font-weight: bold">
#
# ## Part B: Summarising data

# %% [markdown]
# In this section you will use data summarisation techniques (eg. aggregates, visualisation) to answer questions about the data. Your code needs to generate plots that are fully detailed (eg. xlabels, ylabels) and that clearly provide information to answer the question. You need to provide a worded response in Markdown that interprets the information in the plot to clearly answer the question. You should use your judgement on what aggregates and plot types would be most suitable to answer each question.

# %% [markdown]
# ### B1: Which 10 sites have the highest road traffic?
# Write your worded response here.

# %%
# write code here

# %% [markdown]
# ### B2: How do the traffic counts vary by day of the week (Mon, Tues, etc.)?
#
# Write your worded response here

# %%
# write code here

# %% [markdown]
# ### B3: How do traffic counts vary by time of the day?
# Write your worded response here.

# %%
# write code here

# %% [markdown]
# ### B4: How do traffic counts vary by location?
# Write your worded response here.

# %%
# write code here

# %% [markdown]
# ### B5: Your own research question - replace this title with your question
# Write your worded response here.

# %%
# write code here

# %% [markdown]
# <div style="background-color: #b2efb2; padding:10px; font-size:small; font-weight: bold">
#
# ## Part C: Data integration

# %% [markdown]
# In this exercise you will create a simple program that allows someone to find nearby sites and visualise how hour, day of week and direction all affect traffic counts.

# %% [markdown]
# ### C1: Finding closest site
# Create a user-defined function that accepts two inputs: a latitute and a longitude. It should work out how far away each site is using Haversine distance and return the ids of the 5 sites that are closest along with the distance for each site.

# %%
def find_close_sites(latitude, longitude):
    pass     # write your code here

# %%
# add your own test cases here to make sure the function is working correctly.

# %% [markdown]
# ### C2: Site summary
# Create a user-defined function that has one input: a site id. The function should should display a graphic that summarises traffic count data for that site. The graphic should contain two axes - one for the gazettal direction and another for the against gazettal direction. The plot on each set of axes should contain 7 line graphs showing the traffic counts by hour - one for each day of the week. It should be sufficiently labelled, including the site id in the titles of the plot. An example output is pictured below for site 23865 to give a clear indication of what is expected. If the site id is not found in the data, the function should instead display some text to notify the user.
#
# ![C2 example.png](attachment:51a1b743-5f62-468a-b289-f69f4d0ddca3.png)

# %%
def site_summary(site_id):
    pass # write you code here

# %%
# add your own test cases here to make sure the function is working correctly.

# %% [markdown]
# ## C3: Creating a simple app
# Create a user-defined function with two inputs - latitude and longitude. The function should display a string that tells the user what the 5 closest sites are and their distances ask them to select one using the <code>input</code> function. The function should then display the site summary for the selected option as described in C2. If the site id provided by the user doesn't match one of 5 options, the user should be re-prompted to select one from the list. It should re-prompt up to five times before exiting.

# %%
def traffic_app(latitude, longitude):
    pass # write you code here

# %%
# add your own test cases here to make sure the app is working correctly.

# %% [markdown]
# <div style="background-color: #b2efb2; padding:10px; font-size:small; font-weight: bold">
#
# ## Part D: Learning reflection (approx 500 words)

# %% [markdown]
# <p>Write a reflection of your learning from completing this assignment in the Markdown cell below.
#
# Examples of things you might want to discuss include:
# * Programming / data processing concepts you learned.
# * Errors you made and how you troubleshooted them.
# * Earlier drafts of code and how you improved them.
# * Resources from EGD103 you found most useful when completing the assignment.
# * Good programming / data processing practices you developed.
# * Areas of improvement.
#
# The word count is suggestive and won't be rigidly enforced as a limit. Supplementary code provided will not be counted towards the word count.
# </p>

# %% [markdown]
# Write your summary here, making sure to demonstrate some basic Markdown features to format the text (eg. subheadings, bullet points, etc.)

# %%
# Can insert any code that supports your reflection here
# (eg. initial errors you made, earlier versions of code that you improved on)
