# %% [markdown]
# <div style="background-color: #ccccff ; padding:10px; font-size:x-large; font-weight: bold">
# EGD103 Assignment 2 - Analysing Tidal Data in QLD
# </div>

# %% [markdown]
# In this assignment, you will be analysing tide level data off the coast of QLD. This data is collected and made publicly available by the QLD Government's Departent of Environment, Tourism, Science and Innovation.
#
# The main dataset for this assignment ‘QLD_tidal_levels.csv’ is publicly available
# data collected from the Queensland Government’s Open Data Portal.  Raw data was collected from https://www.data.qld.gov.au/dataset/coastal-data-system-tide-data.
# A data dictionary named ‘field-descriptions.csv’ is available. This gives a
# description of each variable in the dataset. Please refer to it if you are unsure
# about what information is contained in each column.
#
# The assignment is split into four parts which are equally weighted:
# * **Part A:** Here you will import, inspect and clean the data to ensure it is suitable for analysis.
# * **Part B:** Here you will use aggregation and visualisation to answer some questions about the data.
# * **Part C:** Here you will integrate some programming theory with the data to create a program.
# * **Part D:** Here you will reflect on your learning from completing the assignment.
#
# You will also be marked on your presentation and code quality as well as an in-class activity after assignment submission. View the CRA on Canvas for more details on how you will be graded.

# %% [markdown]
# <div style="background-color: #ffcccc; padding:10px">
#
# ## General Rules and Restrictions
# * You must use Jupyter in the cloud (on https://jupyter.eres.qut.edu.au) to develop your solution.
# * For the assignments you cannot work with friends or colleagues, or get help from anyone other than the EGD103 teaching team - it needs to be entirely your own work.
# * You cannot use AI tools such as ChatGPT or Copilot to help develop your solution.
# * You can use the imports included in this template to complete this assignment. If you would like to use additional imports you will need approval from the unit coordinator.
# * You should be using formatted Markdown cells to communicate your process and outcomes in each section of the assignment. Clear communication and formatting are required to achieve high marks.
# * You may add extra code cells and Markdown cells to this template at your discretion, but do not remove any cells.
# * You should aim to use Python language features that have been taught within this unit. If you use any other language features, provide a link or citation for where you found them.
# </div>

# %% [markdown]
# <div style="background-color: #b2efb2; padding:10px; font-size:small; font-weight: bold">
#
# ## Student Details
# <p>Task: Using the Markdown cell below, write your name and student number. Also briefly describe any previous programming experience you may have had (if any).</p>

# %% [markdown]
# * Name:
# * Student number:
# * Previous programming experience:

# %% [markdown]
# ## Allowed Imports
# You are allowed to use the imports given in the cell below when completing the assignment. Run the cell to import. Do not repeat yourself by adding import statements later in the assignment.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ***

# %% [markdown]
# <div style="background-color: #b2efb2; padding:10px; font-size:small; font-weight: bold">
#
# ## Part A: Inspecting and preparing data

# %% [markdown]
# ### A1: Importing data
# Import the data as a pandas dataframe, ensuring to make the _id column the index and to parse any date/time related columns in DateTime format. Inspect the data to ensure it has been imported correctly.

# %%
# write your code here

# %% [markdown]
# ### A2: Inspecting data
# Use appropriate pandas attributes/methods to inspect the data and answer the following questions:
# 1. What data types are present in the data?
# 2. How many different sites are in the data?
# 3. Over what date/time range does the data cover

# %%
# write your code here

# %% [markdown]
# ### A3: Filtering data
# You should see from A2 that the last day is only partially complete in the data. Filter out this last day to leave just 7 complete days of data.

# %%
# write code here

# %% [markdown]
# ### A4: Missing values
# When water level data is missing due to broken sensors, a placeholder value has been used in the data. Inspect to find what this placeholder value is, and then replace each of these placeholder values with a missing value (eg. np.nan), so that they don't incorrectly skew your analysis later on.
#
# Hint: The <code>replace</code> method will be useful here.

# %%
# write code here

# %% [markdown]
# ### A5: Site analysis
# Data collectors have told you that the water levels recorded at a few of the sites are likely incorrect due to faulty equipment. Inspect the water level data at each site and specify which sites you believe are faulty. Filter the faulty sites out of the data.

# %%
# write code here

# %% [markdown]
# <div style="background-color: #b2efb2; padding:10px; font-size:small; font-weight: bold">
#
# ## Part B: Summarising Data

# %% [markdown]
# ### B1: Which site has the biggest tidal variance (difference between highest tide and lowest tide reading)?

# %%
# write code here that returns the answer

# %% [markdown]
# ### B2: How do the water levels and predictions compare over time for the Abellpoint site? When are the predictions least accurate?
# Write worded response here that interprets information in the plot.

# %%
# write code here that outputs a plot relevant to answering the question

# %% [markdown]
# ### B3: How are the residuals distributed for each site in the data? Based on this, which sites have accurate predictions? Which sites have inaccurate predictions?
# Write worded response here that interprets information in the plot.

# %%
# write code here that outputs a plot relevant to answering the question

# %% [markdown]
# ### B4: Which two sites are geographically closest in the data? What kind of relationship is there between the water levels at these two sites?
# Write worded response here that interprets information from your code.

# %%
# write code here that outputs numbers and a plot relevant to answering the question

# %% [markdown]
# ### B5: Write your own research question here, then answer it below.
# Write worded response here that interprets information in the plot.

# %%
# write code here that outputs a plot relevant to answering the question

# %% [markdown]
# <div style="background-color: #b2efb2; padding:10px; font-size:small; font-weight: bold">
#
# ## Part C: Data Integration

# %% [markdown]
# In this part you will create a simple program that forecasts water levels in the future and then compare it to the QLD government predictions. To make this easier, we will focus just on one site - Abellpoint.

# %%
# Filter the data for Abellpoint and store in a variable. Use this dataframe for all questions in part C.

# %% [markdown]
# ### C1: Adding new columns
# Add two new columns to the dataframe, one that includes the water levels from 10 mins earlier, and another including the water levels from 10 mins earlier.
#
# Hint: You can use the <code>shift</code> method.

# %%
# write code here

# %% [markdown]
# ### C2: Forecasting using previous water levels
# Add a new column to the dataframe that forecasts what the water level in each row using the water levels from 10 mins and 20 mins earlier. You should use a linear forecasting trend like the equation below:
# $$h = h_{prev} + \Delta h_{prev}$$

# %%
# write code here

# %% [markdown]
# ### C3: Comparing model errors
# Compute the Root Mean Square Error (RMSE) your forecasting model, as well as the predictions contained in the data. You should find your forecasts have less error on average. For more info on RMSE, look here: https://en.wikipedia.org/wiki/Root_mean_square_deviation

# %%
# write code here

# %% [markdown]
# ### C4: Forecasting further ahead
# While your model from C2 is accurate, it only forecasts 10 mins into the future which isn't very long. Define a function below that can forecast any multiple of 10 mins, $\Delta t$, into the future using the water levels from $\Delta t$ mins and $2 \times \Delta t$ mins earlier. The function should output the RMSE of the forecasts.
#
# Afterwards, test your function on $\Delta t = 10$ to confirm you return the same value you got from C3. Then test your function on $\Delta t = 100$ to show that your model has much more error when having to forecast 100 mins into the future.

# %%
# write code here

# %% [markdown]
# ### C5: Recommend when to use your forecasts
# Compare your forecasting model to the governments prediction model for different forecasting times by using a loop to repeatedly call your function from C4. Provide a recommendation to the Government about when your forecasts are more accurate than the Governments.

# %%
# write code here

# %% [markdown]
# <div style="background-color: #b2efb2; padding:10px; font-size:small; font-weight: bold">
#
# ## Part D: Learning Reflection

# %% [markdown]
# ### D1: Explain how your programming approach changed between assignment 1 and assignment 2.
# Write response here (approx 100 words).

# %% [markdown]
# ### D2: Provide an example of a draft piece of code you wrote for this assignment that was incorrect or suboptimal. Describe the process you followed to identify problems with the code and correct them.
# Write response here (approx 100 words).

# %%
# copy the draft code here

# %%
# copy improved code here

# %% [markdown]
# ### D3: Which weekly topic in EGD103 have you found most challenging? What learning resources did you find most helpful to learn this topic?
# Write response here (approx 100 words).

# %% [markdown]
# ### D4: Discuss an example of an engineering problem you might want to solve with programming and/or data processing. What concepts from the unit do you think will be most helpful? What concepts from outside the unit scope might you need to research?
# Write response here (approx 200 words).
