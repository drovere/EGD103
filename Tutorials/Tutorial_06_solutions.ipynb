# %% [markdown]
# # Tutorial: Strings, Sets and Dictionaries
#
# ### Python Concepts:
# * Letting code interact with non-programmers with user input and formatted output.
# * Processing large pieces of text using string methods.
# * Using sets and dictionaries as collections of data.
#
# ### Exercises
# [User Input and Formatted Output](#user_input)
#
# [Working with Strings](#strings)
#
# [Sets](#sets)
#
# [Dictionaries](#dictionaries)
#
# [Extension: Account Details Database](#extension)

# %% [markdown]
# ___
# <a id="user_input"></a>
# ## User Input and Formatted Output Strings
# User input and formatted output strings are useful for creating code that will interact with people who aren't programmers. A simple example of a cost calculator is shown below.

# %% [markdown]
# ### Example: Cost calculator

# %%
def cost_calculator():
    item_cost = input('How much (in dollars) does a single item cost?')
    n_items = input('How many items would you like to purchase?')
    cost = float(item_cost) * float(n_items)
    
    print(f'It will cost ${cost} to purchase {n_items} items that cost ${item_cost} each.')

# %%
cost_calculator()
# Out:
# How much (in dollars) does a single item cost? 2
# How many items would you like to purchase? 5
# It will cost $10.0 to purchase 5 items that cost $2 each.

# %% [markdown]
# ### Exercise: Height Converter
# Create a function that asks for someones height measured in metres. The function should convert the height to feet and inches and output the result as a formatted string.
#
# Hint: There are 39.37 inches in a metre, and 12 inches in a foot. The floored division <code>//</code> and modulo <code>%</code> operators are useful here.

# %%
def height_converter():
    height = float(input('What is your height in metres?'))
    total_inches = height * 39.37
    feet = total_inches // 12
    inches = total_inches % 12

    print(f'Your height is {feet} feet and {inches} inches.')

# %%
# call the function here to test if it works
height_converter()
# Out:
# What is your height in metres? 1.78
# Your height is 5.0 feet and 10.078599999999994 inches.

# %% [markdown]
# ___
# <a id="strings"></a>
# ## Working with Strings
# Often in programming we are required to extract certain features from a piece of text. For example, you might want to find the most frequently used words from a collection of product reviews to capture how people feel about the product. This typically involves the use of string methods and loops. There are lots of string methods, so in this tutorial we will suggest useful methods to you.
#
# The test cases for the following exercises will be two quotes from Hamlet.

# %%
quote_1 = """To be, or not to be: that is the question:
Whether 'tis nobler in the mind to suffer
The slings and arrows of outrageous fortune,
Or to take arms against a sea of troubles,
And by opposing end them. To die: to sleep..."""

# %%
quote_2 = """This above all: to thine own self be true,
And it must follow, as the night the day,
Thou canst not then be false to any man."""

# %% [markdown]
# ### Example: Words in text

# %%
# you can access each word using the split method
quote_1_words = quote_1.split()
quote_1_words
# Out:
# ['To',
#  'be,',
#  'or',
#  'not',
#  'to',
#  'be:',
#  'that',
#  'is',
#  'the',
#  'question:',
#  'Whether',
#  "'tis",
#  'nobler',
#  'in',
#  'the',
#  'mind',
#  'to',
#  'suffer',
#  'The',
#  'slings',
#  'and',
#  'arrows',
#  'of',
#  'outrageous',
#  'fortune,',
#  'Or',
#  'to',
#  'take',
#  'arms',
#  'against',
#  'a',
#  'sea',
#  'of',
#  'troubles,',
#  'And',
#  'by',
#  'opposing',
#  'end',
#  'them.',
#  'To',
#  'die:',
#  'to',
#  'sleep...']

# %%
# You will notice that there is punctuation attached to some of the words. Some of the words also start with capital letters. 
# This can be cleaned up with the lower method and the strip method.
# The function provided below uses these to list all the words contained in a piece of text.
def get_words(text):
    import string
    uncleaned_words = text.lower().split() # convert to lower case and split at each space

    # for loop to strip punctuation from each word
    cleaned_words = []
    for word in uncleaned_words:
        cleaned_word = word.strip(string.punctuation)
        cleaned_words.append(cleaned_word)
    return cleaned_words

# %%
# test case:
get_words(quote_2)
# Out:
# ['this',
#  'above',
#  'all',
#  'to',
#  'thine',
#  'own',
#  'self',
#  'be',
#  'true',
#  'and',
#  'it',
#  'must',
#  'follow',
#  'as',
#  'the',
#  'night',
#  'the',
#  'day',
#  'thou',
#  'canst',
#  'not',
#  'then',
#  'be',
#  'false',
#  'to',
#  'any',
#  'man']

# %% [markdown]
# Now that you have the function <code>get_words</code> to store all the cleaned words in a list, you can attempt the exercises below.

# %% [markdown]
# ### Exercise: Word Count
# Create a function that counts the number of words in a piece of text. Then test your function by calling it on the two example texts. Remember you can call the <code>get_words</code> function.

# %%
def word_count(text):
    words = get_words(text)
    return len(words)

# %%
# test case 1 - should return 43
word_count(quote_1)
# Out:
# 43

# %%
# test case 2 - should return 27
word_count(quote_2)
# Out:
# 27

# %% [markdown]
# ___
# <a id="sets"></a>
# ## Sets

# %% [markdown]
# ### Exercise: Finding all unique words in a piece of text
# Suppose we instead were interested in each unique word in a piece of text. A convenient way to achieve this is to store each word in a set. A set does not allow duplicate entries, so will only display each word once.
#
# Create a function that accepts a piece of text, and that returns all the unique words (ie. removing duplicate entries).

# %%
def unique_words(text):
    words = get_words(text)
    return set(words)

# %%
# test case - should return a set containing all the unique cleaned words in the text
unique_words(quote_1)
# Out:
# {'a',
#  'against',
#  'and',
#  'arms',
#  'arrows',
#  'be',
#  'by',
#  'die',
#  'end',
#  'fortune',
#  'in',
#  'is',
#  'mind',
#  'nobler',
#  'not',
#  'of',
#  'opposing',
#  'or',
#  'outrageous',
#  'question',
#  'sea',
#  'sleep',
#  'slings',
#  'suffer',
#  'take',
#  'that',
#  'the',
#  'them',
#  'tis',
#  'to',
#  'troubles',
#  'whether'}

# %% [markdown]
# ### Exercise: Finding words shared between two texts
# Another benefit of working with sets is you gain access to set operations such as intersection and union. We can use intersection (either the & operator or intersection method) to easily find which words are shared between two pieces of text.
#
# Create the function below which accepts two arguments which are strings. It should ouput the set of words that the two texts share in common.

# %%
def shared_words(text1, text2):
    words1 = unique_words(text1)
    words2 = unique_words(text2)
    return words1 & words2

# %%
# test case - should return {'and', 'be', 'not', 'the', 'to'}
shared_words(quote_1, quote_2)
# Out:
# {'and', 'be', 'not', 'the', 'to'}

# %% [markdown]
# ___
# <a id="dictionaries"></a>
# ## Dictionaries
# A dictionary is a collection of unique identifiers (called keys) that have some information associated with them (called values). For these exercises, we will get you to create a dictionary to store information corresponding to each word, such as its length or the frequency in which it appears in a text.

# %% [markdown]
# ### Example: Word Lengths
# The example below shows how each unique word can be stored as the keys of a dictionary, and its length is stored as the corresponding value. We have called the unique_words function from earlier in the tutorial to simplify the task.

# %%
def word_lengths(text):
    words = unique_words(text) # must have completed earlier exercise for this to work
    word_dictionary = {}
    for word in words:
        word_dictionary[word] = len(word)
    
    return word_dictionary

# %%
word_lengths(quote_1)
# Out:
# {'or': 2,
#  'troubles': 8,
#  'in': 2,
#  'mind': 4,
#  'die': 3,
#  'and': 3,
#  'fortune': 7,
#  'the': 3,
#  'is': 2,
#  'slings': 6,
#  'to': 2,
#  'arrows': 6,
#  'against': 7,
#  'sea': 3,
#  'sleep': 5,
#  'end': 3,
#  'outrageous': 10,
#  'opposing': 8,
#  'by': 2,
#  'tis': 3,
#  'arms': 4,
#  'be': 2,
#  'take': 4,
#  'whether': 7,
#  'not': 3,
#  'question': 8,
#  'nobler': 6,
#  'suffer': 6,
#  'of': 2,
#  'a': 1,
#  'that': 4,
#  'them': 4}

# %% [markdown]
# ### Exercise: Word Frequency Counter
# Create a function that reads through a piece of text. It should ouput a dictionary where the keys are each unique word in the text, and the values are the frequency of that word (how many times it appeared in the text).

# %%
def word_frequency(text):
    frequencies = {}
    words = get_words(text)

    for word in words:
        if word not in frequencies:
            frequencies[word] = 1
        else:
            frequencies[word] += 1

    return frequencies

# %%
# test case
word_frequency(quote_1)
# Out:
# {'to': 6,
#  'be': 2,
#  'or': 2,
#  'not': 1,
#  'that': 1,
#  'is': 1,
#  'the': 3,
#  'question': 1,
#  'whether': 1,
#  'tis': 1,
#  'nobler': 1,
#  'in': 1,
#  'mind': 1,
#  'suffer': 1,
#  'slings': 1,
#  'and': 2,
#  'arrows': 1,
#  'of': 2,
#  'outrageous': 1,
#  'fortune': 1,
#  'take': 1,
#  'arms': 1,
#  'against': 1,
#  'a': 1,
#  'sea': 1,
#  'troubles': 1,
#  'by': 1,
#  'opposing': 1,
#  'end': 1,
#  'them': 1,
#  'die': 1,
#  'sleep': 1}

# %% [markdown]
# ### Exercise: Sorting a Dictionary
# You will have noticed that the dictionary entries aren't sorted in alphabetical order: the order is based on when the word was entered into the dictionary. Create a function below that accepts a dictionary input and outputs a dictionary where the keys have been sorted in alphabetical order.

# %%
def sort_dictionary(dictionary):
    sorted_keys = sorted(dictionary.keys())
    sorted_dictionary = {}

    for key in sorted_keys:
        sorted_dictionary[key] = dictionary[key]

    return sorted_dictionary

# %%
# test your code here by calling it on a dictionary
word_dict = word_frequency(quote_1)
sort_dictionary(word_dict)
# Out:
# {'a': 1,
#  'against': 1,
#  'and': 2,
#  'arms': 1,
#  'arrows': 1,
#  'be': 2,
#  'by': 1,
#  'die': 1,
#  'end': 1,
#  'fortune': 1,
#  'in': 1,
#  'is': 1,
#  'mind': 1,
#  'nobler': 1,
#  'not': 1,
#  'of': 2,
#  'opposing': 1,
#  'or': 2,
#  'outrageous': 1,
#  'question': 1,
#  'sea': 1,
#  'sleep': 1,
#  'slings': 1,
#  'suffer': 1,
#  'take': 1,
#  'that': 1,
#  'the': 3,
#  'them': 1,
#  'tis': 1,
#  'to': 6,
#  'troubles': 1,
#  'whether': 1}

# %%
# optional: can you create a function that sorts the dictionary by value instead of by key?

# %% [markdown]
# ___
# <a id="extension"></a>
# ## Extension Exercise: Account Details Database
# You have likely had to create an online account many times throughout your life. The process typically starts by creating an account which needs a username and a password. Once an account is created, you can then log in to your account my providing your username and password.
#
# In the lecture we explored logging in to an account. In this exercise you will look at account creation.

# %% [markdown]
# ### Creating an Account
# You should create a function that firstly asks the user for their username. If the username doesn't exist in the login_details dictionary, they can then be asked to enter a password. If the username does exist, they should be given a message that says that the username is already taken. It should then prompt them once again to enter a username.
#
# When the user is asked to enter a password, your code must check that it is a strong password. It needs to have 12+ characters and must contain at least one lower case letter, one upper case letter and one number. You should look through the different string methods that are available to work out how to do these checks. If the password is strong, then the code should store the username as a key of the dictionary and the password as its corresponding value. Otherwise, the code should tell the user that it didn't follow the rules of a strong password and should ask them again to enter a password.
#
# You might choose to break the problem up into several function (eg. one for username, one for password) if you wish.

# %%
# creating an empty dictionary to store login details
login_details = {}

# %%
def create_account():
    print('Creating a new account')
    
    valid_username = False
    while not valid_username:
        username = input('Enter a username')
        if username not in login_details:
            valid_username = True
        else:
            print('Username is already taken. Enter a different username.')
    
    valid_password = False
    while not valid_password:
        password = input('Enter a password')
        if len(password) < 12:
            print('Password is too short - must contain at least 12 characters.')
            continue
        has_number = False
        has_lowercase = False
        has_uppercase = False
        for char in password:
            if char.isdigit():
                has_number = True
            elif char.islower():
                has_lowercase = True
            elif char.isupper():
                has_uppercase = True
        if has_number and has_lowercase and has_uppercase:
            valid_password = True
            login_details[username] = password
        else:
            print('Password is not strong enough - must contain at least one lower case letter, upper case letter and a number.')

                
    print('Account created')

# %%
# test function
create_account()
# Out:
# Creating a new account
# Enter a username abc123
# Enter a password password
# Password is too short - must contain at least 12 characters.
# Enter a password reallylongpassword
# Password is not strong enough - must contain at least one lower case letter, upper case letter and a number.
# Enter a password Reallylongpassword123
# Account created

# %%
# test that details are being added to dictionary
login_details
# Out:
# {'abc123': 'Reallylongpassword123'}
