# %% [markdown]
# # Lecture 6: Strings, Sets and Dictionaries

# %% [markdown]
# ## Strings
# Strings are a sequence of characters used to form a piece of text. You can create a string with single quotes 'example string' or double quotes "another example string". A multi-line quote is created by using three quotes.
# * Since they are a sequence type, you can apply sequence operations, index, slice, and iterate through each character with a for loop
# * String methods allow for text to be processed easily
# * Can use the input function to ask the user for an input
# * Can use a formatted string to clearly communicate messages to the user
#
# More details can be found here: https://docs.python.org/3/library/stdtypes.html#text-sequence-type-str

# %%
# examples (in class)

# %%
example_str = 'Hello'

# %%
example_str_2 = "My name is Dave."

# %%
type(example_str)
# Out:
# str

# %%
multi_line_str = '''
KGEJNWAK;JVN
SDKABVKJAN
AVKJWNADVKLJNWA
'''

# %%
# can do sequencey things with strings
# eg. can index
example_str[0]
# Out:
# 'H'

# %%
# eg. can slice
example_str_2[2:7]
# Out:
# ' name'

# %%
# can iterate
for char in example_str:
    print(char)
# Out:
# H
# e
# l
# l
# o

# %%
# strings are immutable (can't be modified) like tuples
example_str[0] = 'h'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # strings are immutable (can't be modified) like tuples
# ----> 2 example_str[0] = 'h'
#
# TypeError: 'str' object does not support item assignment

# %%
# eg. len function still useful
len(example_str)
# Out:
# 5

# %%
# +, *, in operators useful like they were for lists
example_str * 5
# Out:
# 'HelloHelloHelloHelloHello'

# %%
'a' in example_str
# Out:
# False

# %%
# user supplied input
rating = int(input('What is your chess rating?'))
rating_goal = int(input('What chess rating would you like to reach?'))

# formatted output
f"You are {rating_goal - rating} points away from your desired rating. Work hard and you'll get there"
# Out:
# What is your chess rating? 800
# What chess rating would you like to reach? 1000
# "You are 200 points away from your desired rating. Work hard and you'll get there"

# %%
# string methods are really useful!
example_str_2.split()
# Out:
# ['My', 'name', 'is', 'Dave.']

# %%
example_str_2.lower()
# Out:
# 'my name is dave.'

# %% [markdown]
# ## Sets
# A set is an unordered collection of data where each value is unique. Sets are mutable, so you can change the values stored in a set. A set can be created with curly braces eg. {1, 2, 3} or with the set function.
# * Cannot index since a set is unordered
# * Can iterate through a set with a for loop
# * Offer a convenient way to remove duplicate entries from a list - just convert it to a set!
# * Give access to set operations like intersection and union
#
# More details can be found here: https://docs.python.org/3/library/stdtypes.html#set-types-set-frozenset

# %%
# examples (in class)
# create a set with curly braces
games = {'chess', 'monopoly', 'checkers', 'darts'}
games
# Out:
# {'checkers', 'chess', 'darts', 'monopoly'}

# %%
# sets are unordered (lists and tuples are ordered)
# can't index because unordered
games[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 # sets are unordered (lists and tuples are ordered)
# ----> 2 games[0]
#
# TypeError: 'set' object is not subscriptable

# %%
# sets cannot contain duplicate elements
numbers = {2, 5, 4, 2, 1, 1, 3, 3, 6, 9, 2, 4}
numbers
# Out:
# {1, 2, 3, 4, 5, 6, 9}

# %%
# sets can be modified like lists (mutable)
# mainly use methods to do this
numbers.add(11)
numbers
# Out:
# {1, 2, 3, 4, 5, 6, 9, 11}

# %%
# application - remove duplicate entries simply
numbers = [2, 5, 4, 1, 2, 3, 4, 6, 7, 2, 4, 3, 1, 2, 3]
unique_numbers = set(numbers)
unique_numbers
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
# application - using set operations (or methods)
musicals = {'cats', 'chess', 'liono king'}
games & musicals # game and musical
# Out:
# {'chess'}

# %%
games | musicals # game or musical
# Out:
# {'cats', 'checkers', 'chess', 'darts', 'liono king', 'monopoly'}

# %%
games - musicals # game but not a musical
# Out:
# {'checkers', 'darts', 'monopoly'}

# %%
# creating an empty set to add things to later on
empty_set = set()
type(empty_set)
# Out:
# set

# %% [markdown]
# ## Dictionaries
# A dictionary is a set of key : value pairs. The key serves as some unique identifier, and the value provides some information associated with that key. You can create a dictionary with curly braces.
# * Dictionaries use a named index (the key name) rather than a positional index.
# * Ordered based on when entry was added to dictionary.
# * Can use the keys method to access dictionary keys, the values method to access dictionary values, and the items method to access both.
# * Can iterate through the keys or values (or both) with a for loop.
# * A good way to represent data or physical objects.
#
# More details can be found here: https://docs.python.org/3/library/stdtypes.html#mapping-types-dict

# %%
# examples (in class)
items = {'potion': 2, 'pokeball': 5, 'antidote': 1}
items
# Out:
# {'potion': 2, 'pokeball': 5, 'antidote': 1}

# %%
# index using label, not position
items['pokeball']
# Out:
# 5

# %%
# dictionaries can't contain duplicate keys
items = {'potion': 2, 'pokeball': 5, 'antidote': 1, 'potion': 3}
items
# Out:
# {'potion': 3, 'pokeball': 5, 'antidote': 1}

# %%
# dictionary methods are really useful
items.keys()
# Out:
# dict_keys(['potion', 'pokeball', 'antidote'])

# %%
items.values()
# Out:
# dict_values([3, 5, 1])

# %%
# convert dictionary into list of 2-element tuples
# very useful for iteration!
items.items()
# Out:
# dict_items([('potion', 3), ('pokeball', 5), ('antidote', 1)])

# %%
for item, quantity in items.items():
    print(f'You have {quantity} amount of {item} in your bag.')
# Out:
# You have 3 amount of potion in your bag.
# You have 5 amount of pokeball in your bag.
# You have 1 amount of antidote in your bag.

# %%
# dictionaries are mutable (can modify)
# will add a new entry if the key doesn't exist yet
items['nugget'] = 1
items
# Out:
# {'potion': 3, 'pokeball': 5, 'antidote': 1, 'nugget': 1}

# %%
# will replace if the key does exist
items['potion'] = 1
items
# Out:
# {'potion': 1, 'pokeball': 5, 'antidote': 1, 'nugget': 1}

# %% [markdown]
# ### Activity: Account Login
# Design a simple program that gets someone to log in to their account. It must have the following functionality:
# * All usernames and passwords that exist are stored as key: value pairs in a dictionary.
# * The function should ask the user for their username and password.
# * The function should give the user a maximum of 3 incorrect login attempts before locking their account.

# %%
# create a dictionary that contains some username: password pairs.
login_details = {'user1': 'password', 'user2': 'sdfgoknsdgo', 'mr_hacker': '1234'}

# %%
# define a function that gives the user 3 attempts to log in
def account_login():

    attempts_remaining = 3
    while attempts_remaining > 0:

        # ask for username
        username = input('What is your username?')
        password = input('What is your password?')

        # test whether username password combination is correct
        if username in login_details and password == login_details[username]:
            print('Successful login.')
            return
        else:
            attempts_remaining = attempts_remaining - 1
            print(f'Username or password are incorrect. You have {attempts_remaining} attempts remaining.')
        
    # print if all 3 attempts are unsuccessul
    print('You have used all three login attempts. Your account will be locked for 24 hours for security reasons.')

# %%
# test 1: correct attempt first time
account_login()
# Out:
# What is your username? user1
# What is your password? password
# Successful login.

# %%
# test 2: correct attempt second time
account_login()
# Out:
# What is your username? user1
# What is your password? 1234
# Username or password are incorrect. You have 2 attempts remaining.
# What is your username? mr_hacker
# What is your password? 1234
# Successful login.

# %%
# test 3: three unsuccessful login attempts
account_login()
# Out:
# What is your username? mr_hacker
# What is your password? password
# Username or password are incorrect. You have 2 attempts remaining.
# What is your username? mr_hacker
# What is your password? sdfknsdv
# Username or password are incorrect. You have 1 attempts remaining.
# What is your username? mr_hacker
# What is your password? sdfndvpeve
# Username or password are incorrect. You have 0 attempts remaining.
# You have used all three login attempts. Your account will be locked for 24 hours for security reasons.
